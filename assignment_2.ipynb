# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = [1.3, 1.5, 2.6, 2.6, 3.2, 3.9, 4.2, 3.7, 3.10, 3.0, 11, 6.7, 1.9]
plt.hist(X, bins=5, density=True, alpha=1, color='black', edgecolor='white')
plt.grid(True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram')
plt.show()

# %%
plt.title('Histogram with Density')
plt.xlabel('Data values')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.array([12,13,56,23,41,28,51])
y = np.array([51,63,37,88,33,72,81])
mean_x = np.mean(x)
print(mean_x)
# Out:
# 32.0

# %%
median_x = np.median(x)
print(median_x)
# Out:
# 28.0

# %%
mode_x =pd.Series(x).mode().values
print(mode_x)
# Out:
# [12 13 23 28 41 51 56]

# %%
variance_x = np.var(x)
print(variance_x)
# Out:
# 268.0

# %%
std_dev_x = np.std(x)
print(std_dev_x)
# Out:
# 16.3707055437449

# %%
range_x = np.max(x)-np.min(x)
print(range_x)
# Out:
# 44

# %%
iqr_x = np.percentile(x, 75) - np.percentile(x, 25)
print(iqr_x)
skewness_x = (3 * (mean_x - median_x)) / std_dev_x
print(skewness_x)
kurtosis_x = np.mean((x - mean_x)**4) / (std_dev_x**4) - 3
print(kurtosis_x)
# Out:
# 28.0
# 0.7330166661378313
# -1.4768402125831401

# %%
mean_y = np.mean(y)
print(mean_y)
median_y = np.median(y)
print(median_y)
variance_y = np.var(y)
print(variance_y)
std_dev_y = np.std(y)
print(std_dev_y)
range_y = np.max(y)-np.min(y)
print(range_y)
# Out:
# 60.714285714285715
# 63.0
# 387.6326530612245
# 19.68838878784205
# 55

# %%
iqr_y = np.percentile(y, 75) - np.percentile(y,25)
print(iqr_y)
skewness_y = (3 * (mean_y - median_y)) / std_dev_y
print(skewness_y)
kurtosis_y = np.mean((y - mean_y)**4) / (std_dev_y**4) - 3
print(kurtosis_y)
# Out:
# 32.5
# -0.3482835965417987
# -1.426529582797266
